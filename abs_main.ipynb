# %% [markdown]
# download audible books and store in a more useful format

# %%
import pandas as pd
import os
import json
import abs_reader
import abs_download

# %%
''' setup folders and files'''
if not 'workbookDir' in globals():          # get the local working directory
    workbookDir = os.getcwd()               # needed to work with local html files
print('working folder is',workbookDir)
download_folder = workbookDir + '\\downloads\\'
csvfile = workbookDir + '\\books.csv'
# Out:
# working folder is c:\Users\Willi\OneDrive\Repos\Audible-book-scraper

# %%
'''download html files'''
with open('urls.json') as r:
    pages_to_download = json.load(r)
abs_download.download_html(pages_to_download,download_folder,1)
# Out:
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\sff1.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\sff2.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\sff3.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\sff4.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt1.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt2.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt3.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt4.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt5.html already exists, skipping
# c:\Users\Willi\OneDrive\Repos\Audible-book-scraper\downloads\mt6.html already exists, skipping

# %%
'''process html files to csv'''
abs_reader.process_folder(download_folder,csvfile,1)
# Out:
# 433 books processed

# %%
df_books = pd.read_csv(csvfile)
df_books.sort_values('ratings',ascending=False).head(20)
# Out:
#      Unnamed: 0                                             name  \
# 331          11                                    The Last Wish
# 276           6                                       Steelheart
# 325           5                                 Children of Time
# 142          42                            The Secrets She Keeps
# 341          21                     Monster Hunter International
# 355          35                                         Watchers
# 332          12                                 Sword of Destiny
# 290          20                               Agent to the Stars
# 165          15                                         The Poet
# 5             5                                   Into the Water
# 178          28                                Her Royal Spyness
# 2             2                                       Still Life
# 344          24               The Farseer: Assassin's Apprentice
# 6             6                                         Find Her
# 273           3                                  Dead Until Dark
# 278           8                               Second Hand Curses
# 348          28                                        Swan Song
# 349          29                                         The Host
# 171          21                           The Girl Who Was Taken
# 170          20  The Concrete Blonde: Harry Bosch Series, Book 3
#
#                  author  stars  ratings         url  \
# 331   Andrzej Sapkowski    4.5    37149  B00WX7Y0W2
# 276   Brandon Sanderson    4.5    35984  B00ECDZ08I
# 325  Adrian Tchaikovsky    4.5    30995  B071Y9TTHC
# 142    Michael Robotham    4.5    19585  B0716VL73Z
# 341       Larry Correia    4.5    19300  B004RGQ6UQ
# 355         Dean Koontz    4.5    18625  B07D2JG8TH
# 332   Andrzej Sapkowski    5.0    18321  B017WP4D6C
# 290         John Scalzi    4.5    14680  B004DR2CNE
# 165    Michael Connelly    4.5    14357  B002UZN6SQ
# 5         Paula Hawkins    4.0    13112  B01N5P9MG0
# 178          Rhys Bowen    4.0    13085  B003VW6KU8
# 2          Louise Penny    4.5    12186  B00JS9K7OI
# 344          Robin Hobb    4.5    12069  B003AO3P5A
# 6          Lisa Gardner    4.5    12062  B019WKOU18
# 273    Charlaine Harris    4.0    11625  B002V1LPJ6
# 278          Drew Hayes    4.5    11560  B074XK2R2X
# 348  Robert R. McCammon    4.5    11260  B00656GCH8
# 349     Stephenie Meyer    4.5    10926  B002V0PS5E
# 171      Charlie Donlea    4.5    10401  B06ZZ22PP1
# 170    Michael Connelly    4.5    10352  B002V1CBTY
#
#                           full url
# 331  www.audible.com/pd/B00WX7Y0W2
# 276  www.audible.com/pd/B00ECDZ08I
# 325  www.audible.com/pd/B071Y9TTHC
# 142  www.audible.com/pd/B0716VL73Z
# 341  www.audible.com/pd/B004RGQ6UQ
# 355  www.audible.com/pd/B07D2JG8TH
# 332  www.audible.com/pd/B017WP4D6C
# 290  www.audible.com/pd/B004DR2CNE
# 165  www.audible.com/pd/B002UZN6SQ
# 5    www.audible.com/pd/B01N5P9MG0
# 178  www.audible.com/pd/B003VW6KU8
# 2    www.audible.com/pd/B00JS9K7OI
# 344  www.audible.com/pd/B003AO3P5A
# 6    www.audible.com/pd/B019WKOU18
# 273  www.audible.com/pd/B002V1LPJ6
# 278  www.audible.com/pd/B074XK2R2X
# 348  www.audible.com/pd/B00656GCH8
# 349  www.audible.com/pd/B002V0PS5E
# 171  www.audible.com/pd/B06ZZ22PP1
# 170  www.audible.com/pd/B002V1CBTY
