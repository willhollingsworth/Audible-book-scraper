# %% [markdown]
# download audible books and store in a more useful format

# %%
import pandas as pd
import os
import json
import abs_reader
import abs_download

# %%
''' setup folders '''
if not 'workbookDir' in globals():          # get the local working directory
    workbookDir = os.getcwd()               # needed to work with local html files
print('working folder is',workbookDir)
download_folder = workbookDir + '\\downloads\\'

# %%
'''download html files'''
with open('urls.json') as r:
    pages_to_download = json.load(r)
abs_download.download_html(pages_to_download,download_folder,1)

# %%
'''process html files'''
df_books = abs_reader.read_folder(download_folder,1)
# Out:
# 433 books processed

# %%
df_books.sort_values('ratings',ascending=False).head(20)
# Out:
#                                                name              author stars  \
# 11                                    The Last Wish   Andrzej Sapkowski  4.5
# 6                                        Steelheart   Brandon Sanderson  4.5
# 5                                  Children of Time  Adrian Tchaikovsky  4.5
# 42                            The Secrets She Keeps    Michael Robotham  4.5
# 21                     Monster Hunter International       Larry Correia  4.5
# 35                                         Watchers         Dean Koontz  4.5
# 12                                 Sword of Destiny   Andrzej Sapkowski    5
# 20                               Agent to the Stars         John Scalzi  4.5
# 15                                         The Poet    Michael Connelly  4.5
# 5                                    Into the Water       Paula Hawkins    4
# 28                                Her Royal Spyness          Rhys Bowen    4
# 2                                        Still Life        Louise Penny  4.5
# 24               The Farseer: Assassin's Apprentice          Robin Hobb  4.5
# 6                                          Find Her        Lisa Gardner  4.5
# 3                                   Dead Until Dark    Charlaine Harris    4
# 8                                Second Hand Curses          Drew Hayes  4.5
# 28                                        Swan Song  Robert R. McCammon  4.5
# 29                                         The Host     Stephenie Meyer  4.5
# 21                           The Girl Who Was Taken      Charlie Donlea  4.5
# 20  The Concrete Blonde: Harry Bosch Series, Book 3    Michael Connelly  4.5
#
#     ratings         url                       full url
# 11    37149  B00WX7Y0W2  www.audible.com/pd/B00WX7Y0W2
# 6     35984  B00ECDZ08I  www.audible.com/pd/B00ECDZ08I
# 5     30995  B071Y9TTHC  www.audible.com/pd/B071Y9TTHC
# 42    19584  B0716VL73Z  www.audible.com/pd/B0716VL73Z
# 21    19300  B004RGQ6UQ  www.audible.com/pd/B004RGQ6UQ
# 35    18625  B07D2JG8TH  www.audible.com/pd/B07D2JG8TH
# 12    18321  B017WP4D6C  www.audible.com/pd/B017WP4D6C
# 20    14680  B004DR2CNE  www.audible.com/pd/B004DR2CNE
# 15    14357  B002UZN6SQ  www.audible.com/pd/B002UZN6SQ
# 5     13112  B01N5P9MG0  www.audible.com/pd/B01N5P9MG0
# 28    13085  B003VW6KU8  www.audible.com/pd/B003VW6KU8
# 2     12186  B00JS9K7OI  www.audible.com/pd/B00JS9K7OI
# 24    12069  B003AO3P5A  www.audible.com/pd/B003AO3P5A
# 6     12062  B019WKOU18  www.audible.com/pd/B019WKOU18
# 3     11625  B002V1LPJ6  www.audible.com/pd/B002V1LPJ6
# 8     11560  B074XK2R2X  www.audible.com/pd/B074XK2R2X
# 28    11260  B00656GCH8  www.audible.com/pd/B00656GCH8
# 29    10926  B002V0PS5E  www.audible.com/pd/B002V0PS5E
# 21    10401  B06ZZ22PP1  www.audible.com/pd/B06ZZ22PP1
# 20    10352  B002V1CBTY  www.audible.com/pd/B002V1CBTY
